# %% [markdown]
# # 🚀 ZEFOY AUTO BOT – Google Colab Version
# Chạy tự động 100% trên Cloud của Google không cần laptop!

# %% [markdown]
# ### 1️⃣ Cài đặt môi trường & Chrome

# %%
# Cài đặt Google Chrome Stable
# !apt-get update -y
# !apt-get install -y google-chrome-stable

# Cài các thư viện Python
# !pip install --upgrade pip -q
# !pip install selenium webdriver-manager openai python-dotenv requests Pillow -q
print("✅ Cài đặt môi trường hoàn tất!")

# %% [markdown]
# ### 2️⃣ Tải mã nguồn Zefoy Bot từ GitHub

# %%
# !git clone https://github.com/Han126-Phuc2004/zefoy-bot.git /content/zefoy-bot 2>/dev/null || (cd /content/zefoy-bot && git pull)
# %cd /content/zefoy-bot
print("✅ Đã tải code thành công!")

# %% [markdown]
# ### 3️⃣ Cấu hình & Bắt đầu chạy Bot

# %%
import os

# 🔑 Điền thông tin của bạn vào đây:
API_KEY = "DÁN_API_KEY_OPENROUTER_TẠI_ĐÂY"                                        # API Key OpenRouter
TIKTOK_URL = "https://vt.tiktok.com/ZSxxxxxx/"                                     # Link video TikTok
SERVICE = "4"                                                                       # 4 = Views, 2 = Hearts, 1 = Followers...

# Tạo file .env
with open(".env", "w") as f:
    f.write(f"OPENROUTER_API_KEY={API_KEY}\n")

os.environ["OPENROUTER_API_KEY"] = API_KEY

print(f"🚀 Đang khởi chạy Zefoy Bot cho link: {TIKTOK_URL}")
# !python zefoy_headless.py --service "{SERVICE}" --url "{TIKTOK_URL}"
